# %% [markdown]
# ### Cleaning Data to 2018

# %%
import pandas as pd

df1 = pd.read_csv('../data/rawData/touringplans_2018.csv', quotechar='"', skiprows=[14312, 33475])
display(df1.head())
# Out:
#     park_date  wait_hour         attraction_name  wait_minutes_actual_avg  \
# 0  2018-06-30          7  Alien Swirling Saucers                      NaN
# 1  2018-06-30          8  Alien Swirling Saucers                      NaN
# 2  2018-06-30          9  Alien Swirling Saucers                      NaN
# 3  2018-06-30         10  Alien Swirling Saucers                      NaN
# 4  2018-06-30         11  Alien Swirling Saucers                      NaN
#
#    wait_minutes_posted_avg  attraction_wait_per_hundred_average  \
# 0               150.000000                                 10.0
# 1               127.083333                                 10.0
# 2                91.111111                                 10.0
# 3               136.000000                                 10.0
# 4               173.333333                                 10.0
#
#    attraction_duration             attraction_park attraction_land park_open  \
# 0                  2.5  Disney's Hollywood Studios  Toy Story Land  08:00:00
# 1                  2.5  Disney's Hollywood Studios  Toy Story Land  08:00:00
# 2                  2.5  Disney's Hollywood Studios  Toy Story Land  08:00:00
# 3                  2.5  Disney's Hollywood Studios  Toy Story Land  08:00:00
# 4                  2.5  Disney's Hollywood Studios  Toy Story Land  08:00:00
#
#   park_close  park_extra_magic_morning  park_extra_magic_evening  \
# 0   23:00:00                         0                         0
# 1   23:00:00                         0                         0
# 2   23:00:00                         0                         0
# 3   23:00:00                         0                         0
# 4   23:00:00                         0                         0
#
#   park_ticket_season  park_temperature_average  park_temperature_high  \
# 0               peak                     79.44                  85.29
# 1               peak                     79.44                  85.29
# 2               peak                     79.44                  85.29
# 3               peak                     79.44                  85.29
# 4               peak                     79.44                  85.29
#
#   attraction_short_name
# 0         Alien Saucers
# 1         Alien Saucers
# 2         Alien Saucers
# 3         Alien Saucers
# 4         Alien Saucers

# %%
print("Unique values in 'park_open' column:")
display(df1['park_open'].unique())

print("\nUnique values in 'park_close' column:")
display(df1['park_close'].unique())

print("\nUnique values in 'attraction_park' column:")
display(df1['attraction_park'].unique())
# Out:
# Unique values in 'park_open' column:
# array(['08:00:00', '09:00:00', '07:00:00'], dtype=object)
# Unique values in 'park_close' column:
# array(['23:00:00', '22:30:00', '22:00:00', '21:00:00', '20:30:00',
#        '20:00:00', '24:00:00', '21:30:00', '19:00:00', '18:00:00',
#        '25:00:00', '16:30:00'], dtype=object)
# Unique values in 'attraction_park' column:
# array(["Disney's Hollywood Studios", "Disney's Animal Kingdom",
#        'Magic Kingdom', 'Epcot'], dtype=object)

# %%
animal_kingdom_df1 = df1[(df1['attraction_park'] == "Disney's Animal Kingdom") & (df1['park_open'] != '7:00:00')]
display(animal_kingdom_df1.head())
# Out:
#        park_date  wait_hour attraction_name  wait_minutes_actual_avg  \
# 2718  2018-01-01          8        DINOSAUR                      NaN
# 2719  2018-01-01          9        DINOSAUR                      NaN
# 2720  2018-01-01         10        DINOSAUR                      NaN
# 2721  2018-01-01         11        DINOSAUR                      NaN
# 2722  2018-01-01         12        DINOSAUR                      NaN
#
#       wait_minutes_posted_avg  attraction_wait_per_hundred_average  \
# 2718                15.000000                                  3.0
# 2719                18.333333                                  3.0
# 2720                23.750000                                  3.0
# 2721                24.000000                                  3.0
# 2722                31.875000                                  3.0
#
#       attraction_duration          attraction_park  attraction_land park_open  \
# 2718                  3.5  Disney's Animal Kingdom  DinoLand U.S.A.  08:00:00
# 2719                  3.5  Disney's Animal Kingdom  DinoLand U.S.A.  08:00:00
# 2720                  3.5  Disney's Animal Kingdom  DinoLand U.S.A.  08:00:00
# 2721                  3.5  Disney's Animal Kingdom  DinoLand U.S.A.  08:00:00
# 2722                  3.5  Disney's Animal Kingdom  DinoLand U.S.A.  08:00:00
#
#      park_close  park_extra_magic_morning  park_extra_magic_evening  \
# 2718   20:00:00                         0                         0
# 2719   20:00:00                         0                         0
# 2720   20:00:00                         0                         0
# 2721   20:00:00                         0                         0
# 2722   20:00:00                         0                         0
#
#      park_ticket_season  park_temperature_average  park_temperature_high  \
# 2718               peak                     50.56                  58.63
# 2719               peak                     50.56                  58.63
# 2720               peak                     50.56                  58.63
# 2721               peak                     50.56                  58.63
# 2722               peak                     50.56                  58.63
#
#      attraction_short_name
# 2718              DINOSAUR
# 2719              DINOSAUR
# 2720              DINOSAUR
# 2721              DINOSAUR
# 2722              DINOSAUR

# %%
print("Unique values in 'park_open' column:")
display(animal_kingdom_df1['park_open'].unique())

print("\nUnique values in 'park_close' column:")
display(animal_kingdom_df1['park_close'].unique())

print("\nUnique values in 'attraction_park' column:")
display(animal_kingdom_df1['attraction_park'].unique())
# Out:
# Unique values in 'park_open' column:
# array(['08:00:00', '09:00:00'], dtype=object)
# Unique values in 'park_close' column:
# array(['20:00:00', '21:00:00', '20:30:00', '22:00:00', '21:30:00',
#        '23:00:00', '22:30:00', '19:00:00'], dtype=object)
# Unique values in 'attraction_park' column:
# array(["Disney's Animal Kingdom"], dtype=object)

# %%
df2 = pd.read_csv('../data/rawData/parks_metadata_raw.csv', quotechar='"')
display(df2.head())
# Out:
#          date wdw_ticket_season  dayofweek  dayofyear  weekofyear  \
# 0  2015-01-01               NaN          5          0           0
# 1  2015-01-02               NaN          6          1           0
# 2  2015-01-03               NaN          7          2           0
# 3  2015-01-04               NaN          1          3           1
# 4  2015-01-05               NaN          2          4           1
#
#    monthofyear  year          season  holidaypx  holidaym  ... hsfirewks  \
# 0            1  2015  CHRISTMAS PEAK          0         5  ...         1
# 1            1  2015       CHRISTMAS          2         5  ...         1
# 2            1  2015       CHRISTMAS          3         0  ...         1
# 3            1  2015       CHRISTMAS          4         0  ...         1
# 4            1  2015       CHRISTMAS          5         0  ...         1
#
#    akprdday akprddt1 akprddt2 akprddn  akfiren  akshwngt akshwnt1  akshwnt2  \
# 0         0      NaN      NaN     NaN      NaN         0      NaN       NaN
# 1         0      NaN      NaN     NaN      NaN         0      NaN       NaN
# 2         0      NaN      NaN     NaN      NaN         0      NaN       NaN
# 3         0      NaN      NaN     NaN      NaN         0      NaN       NaN
# 4         0      NaN      NaN     NaN      NaN         0      NaN       NaN
#
#    akshwnn
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 181 columns]

# %%
df2 = df2.drop(['holidayn', 'holidaym', 'holidaypx'], axis=1)
display(df2.head())
# Out:
#          date wdw_ticket_season  dayofweek  dayofyear  weekofyear  \
# 0  2015-01-01               NaN          5          0           0
# 1  2015-01-02               NaN          6          1           0
# 2  2015-01-03               NaN          7          2           0
# 3  2015-01-04               NaN          1          3           1
# 4  2015-01-05               NaN          2          4           1
#
#    monthofyear  year          season  holiday wdwticketseason  ... hsfirewks  \
# 0            1  2015  CHRISTMAS PEAK        1             NaN  ...         1
# 1            1  2015       CHRISTMAS        0             NaN  ...         1
# 2            1  2015       CHRISTMAS        0             NaN  ...         1
# 3            1  2015       CHRISTMAS        0             NaN  ...         1
# 4            1  2015       CHRISTMAS        0             NaN  ...         1
#
#   akprdday  akprddt1  akprddt2 akprddn  akfiren  akshwngt  akshwnt1 akshwnt2  \
# 0        0       NaN       NaN     NaN      NaN         0       NaN      NaN
# 1        0       NaN       NaN     NaN      NaN         0       NaN      NaN
# 2        0       NaN       NaN     NaN      NaN         0       NaN      NaN
# 3        0       NaN       NaN     NaN      NaN         0       NaN      NaN
# 4        0       NaN       NaN     NaN      NaN         0       NaN      NaN
#
#    akshwnn
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 178 columns]

# %%
df2_2018 = df2[df2['year'] == 2018]
display(df2_2018.head())
# Out:
#             date wdw_ticket_season  dayofweek  dayofyear  weekofyear  \
# 1096  2018-01-01              peak          2          0           0
# 1097  2018-01-02              peak          3          1           0
# 1098  2018-01-03              peak          4          2           0
# 1099  2018-01-04           regular          5          3           0
# 1100  2018-01-05           regular          6          4           0
#
#       monthofyear  year          season  holiday wdwticketseason  ...  \
# 1096            1  2018  CHRISTMAS PEAK        1            peak  ...
# 1097            1  2018       CHRISTMAS        0            peak  ...
# 1098            1  2018       CHRISTMAS        0            peak  ...
# 1099            1  2018       CHRISTMAS        0         regular  ...
# 1100            1  2018       CHRISTMAS        0         regular  ...
#
#      hsfirewks akprdday  akprddt1  akprddt2 akprddn  akfiren  akshwngt  \
# 1096         1        0       NaN       NaN     NaN      NaN         2
# 1097         1        0       NaN       NaN     NaN      NaN         2
# 1098         1        0       NaN       NaN     NaN      NaN         2
# 1099         1        0       NaN       NaN     NaN      NaN         2
# 1100         1        0       NaN       NaN     NaN      NaN         2
#
#       akshwnt1 akshwnt2          akshwnn
# 1096   66600.0  71100.0  Rivers of Light
# 1097   66600.0  71100.0  Rivers of Light
# 1098   66600.0  71100.0  Rivers of Light
# 1099   66600.0  71100.0  Rivers of Light
# 1100   66600.0  71100.0  Rivers of Light
#
# [5 rows x 178 columns]

# %%
# Check if all values in 'wdw_ticket_season' are the same as 'season' in df2_2018
are_same = (df2_2018['wdw_ticket_season'] == df2_2018['season']).all()
print(f"Are all values in 'wdw_ticket_season' the same as 'season'? {are_same}")
# Out:
# Are all values in 'wdw_ticket_season' the same as 'season'? False
